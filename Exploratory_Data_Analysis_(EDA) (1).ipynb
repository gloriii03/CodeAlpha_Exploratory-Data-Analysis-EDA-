# %% [markdown]
# B**efore starting EDA, define questions like:**
#
# What is the distribution of positive vs negative reviews?
#
# Are review classes balanced or imbalanced?
#
# How long are reviews on average?
#
# Do positive reviews tend to be longer than negative reviews?
#
# Are there duplicate or missing reviews?
#
# Which words appear frequently in positive and negative reviews?
#
# Are there anomalies such as extremely short or very long reviews?

# %% [markdown]
# Import Libraries

# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %% [markdown]
# Explore Data Structure (Variables & Data Types)

# %%
print("Dataset Shape:")
print(df.shape)
# Out:
# Dataset Shape:
# (3000, 9)

# %%
print("\nColumns:")
print(df.columns)
# Out:
# Columns:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
print("\nDataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
# None

# %% [markdown]
# ### Summary Statistics

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

print("\nDescriptive Statistics:")
display(df.describe())
# Out:
# Descriptive Statistics:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# ### Distribution Analysis of Key Features

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

df.hist(bins=50, figsize=(20, 15))
plt.suptitle('Distribution of Numerical Features')
plt.tight_layout(rect=[0, 0.03, 1, 0.98])
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Features')
plt.show()

# %% [markdown]
# ### Scatterplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

plt.figure(figsize=(10, 6))
sns.scatterplot(x='median_income', y='median_house_value', data=df, alpha=0.6)
plt.title('Median Income vs. Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='total_rooms', y='median_house_value', data=df, alpha=0.6)
plt.title('Total Rooms vs. Median House Value')
plt.xlabel('Total Rooms')
plt.ylabel('Median House Value')
plt.show()

# %% [markdown]
# ### Bar Charts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# Binning housing_median_age for a bar chart
df['age_group'] = pd.cut(df['housing_median_age'], bins=[0, 10, 20, 30, 40, 50, 60], labels=['0-10', '11-20', '21-30', '31-40', '41-50', '51+'])
median_value_by_age = df.groupby('age_group', observed=False)['median_house_value'].mean().reset_index()

plt.figure(figsize=(12, 7))
sns.barplot(x='age_group', y='median_house_value', data=median_value_by_age)
plt.title('Average Median House Value by Housing Median Age Group')
plt.xlabel('Housing Median Age Group')
plt.ylabel('Average Median House Value')
plt.show()

# %% [markdown]
# Identify Trends, Patterns and Anomalies

# %% [markdown]
# Population Distribution Analysis

# %%
print(df["population"].value_counts(normalize=True)*100)
# Out:
# population
# 870.0     0.233333
# 753.0     0.200000
# 697.0     0.200000
# 881.0     0.200000
# 1211.0    0.200000
#             ...
# 2153.0    0.033333
# 2227.0    0.033333
# 1780.0    0.033333
# 299.0     0.033333
# 1186.0    0.033333
# Name: proportion, Length: 1802, dtype: float64

# %% [markdown]
# Distribution of Total Rooms

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

print("Descriptive statistics for Total Rooms:")
print(df["total_rooms"].describe())

plt.figure(figsize=(10, 6))
df["total_rooms"].hist(bins=50)
plt.title('Distribution of Total Rooms')
plt.xlabel('Total Rooms')
plt.ylabel('Frequency')
plt.show()
# Out:
# Descriptive statistics for Total Rooms:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %% [markdown]
# Anomaly Detection for Total Rooms:

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

print("Houses with very few total rooms (e.g., less than 100):")
display(df[df["total_rooms"] < 100].head())

print("\nHouses with a very large number of total rooms (e.g., more than 10000):")
display(df[df["total_rooms"] > 10000].head())
# Out:
# Houses with very few total rooms (e.g., less than 100):
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3      -118.36     33.82                28.0         67.0            15.0
# 564    -121.98     37.14                37.0         74.0            19.0
# 641    -121.04     37.67                16.0         19.0            19.0
# 666    -121.89     37.42                26.0         40.0             8.0
# 733    -117.99     33.81                46.0         38.0             8.0
#
#      population  households  median_income  median_house_value
# 3          49.0        11.0         6.1359            330000.0
# 564        63.0        17.0         9.5908            350000.0
# 641       166.0         9.0         0.5360            162500.0
# 666        52.0         7.0         7.7197            225000.0
# 733        66.0        14.0         4.1667            162500.0
# Houses with a very large number of total rooms (e.g., more than 10000):
# ...

# %% [markdown]
# Test Hypotheses & Validate Assumptions
#
# Hypothesis 1:
#
# H0: Positive and negative reviews have equal average lengths.

# %% [markdown]
# ## Hypothesis Test: Median House Value vs. Housing Median Age
#
# Let's test the hypothesis that the median house value differs significantly between newer and older housing. We'll define 'newer' housing as having a `housing_median_age` of 25 years or less, and 'older' housing as having a `housing_median_age` greater than 25 years.
#
# *   **Null Hypothesis (H0):** There is no significant difference in the mean `median_house_value` between houses with a `housing_median_age` of 25 years or less and those with a `housing_median_age` greater than 25 years.
# *   **Alternative Hypothesis (H1):** There is a significant difference in the mean `median_house_value` between houses with a `housing_median_age` of 25 years or less and those with a `housing_median_age` greater than 25 years.

# %%
from scipy.stats import ttest_ind

nwer_houses = df[df['housing_median_age'] <= 25]['median_house_value']
older_houses = df[df['housing_median_age'] > 25]['median_house_value']

t_stat, p_value = ttest_ind(
    nwer_houses,
    older_houses,
    equal_var=False
)

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value:.3f}")
# Out:
# T-statistic: -4.08
# P-value: 0.000

# %%
alpha = 0.05
if p_value < alpha:
    print(f"\nSince the p-value ({p_value:.3f}) is less than the significance level ({alpha}), we reject the null hypothesis.")
    print("Conclusion: There is a significant difference in the mean median house value between newer and older houses.")
else:
    print(f"\nSince the p-value ({p_value:.3f}) is greater than the significance level ({alpha}), we fail to reject the null hypothesis.")
    print("Conclusion: There is no significant difference in the mean median house value between newer and older houses.")
# Out:
# Since the p-value (0.000) is less than the significance level (0.05), we reject the null hypothesis.
# Conclusion: There is a significant difference in the mean median house value between newer and older houses.

# %% [markdown]
# ## Hypothesis Test: Median Income vs. Median House Value
#
# Let's test if there is a significant linear relationship between the median income of a district and its median house value.
#
# *   **Null Hypothesis (H0):** There is no significant linear correlation between `median_income` and `median_house_value`.
# *   **Alternative Hypothesis (H1):** There is a significant linear correlation between `median_income` and `median_house_value`.

# %%
import pandas as pd
from scipy.stats import pearsonr
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

correlation, p_value_corr = pearsonr(df['median_income'], df['median_house_value'])

print(f"Pearson correlation coefficient: {correlation:.2f}")
print(f"P-value: {p_value_corr:.3f}")
# Out:
# Pearson correlation coefficient: 0.67
# P-value: 0.000

# %% [markdown]
# ### Conclusion for Hypothesis Test: Median Income vs. Median House Value

# %%
alpha = 0.05
if p_value_corr < alpha:
    print(f"\nSince the p-value ({p_value_corr:.3f}) is less than the significance level ({alpha}), we reject the null hypothesis.")
    print("Conclusion: There is a significant linear correlation between median income and median house value.")
else:
    print(f"\nSince the p-value ({p_value_corr:.3f}) is greater than the significance level ({alpha}), we fail to reject the null hypothesis.")
    print("Conclusion: There is no significant linear correlation between median income and median house value.")
# Out:
# Since the p-value (0.000) is less than the significance level (0.05), we reject the null hypothesis.
# Conclusion: There is a significant linear correlation between median income and median house value.

# %% [markdown]
# ### Conclusion for Hypothesis Test: Median Income vs. Median House Value

# %%
alpha = 0.05
if p_value_corr < alpha:
    print(f"\nSince the p-value ({p_value_corr:.3f}) is less than the significance level ({alpha}), we reject the null hypothesis.")
    print("Conclusion: There is a significant linear correlation between median income and median house value.")
else:
    print(f"\nSince the p-value ({p_value_corr:.3f}) is greater than the significance level ({alpha}), we fail to reject the null hypothesis.")
    print("Conclusion: There is no significant linear correlation between median income and median house value.")
# Out:
# Since the p-value (0.000) is less than the significance level (0.05), we reject the null hypothesis.
# Conclusion: There is a significant linear correlation between median income and median house value.

# %% [markdown]
# Detect Data Issues / Problems

# %%
print("Missing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
print("\nDuplicates")
print(df.duplicated().sum())
# Out:
# Duplicates
# 0
